# %% [markdown]
# # Map between two states and get free energy

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %env XLA_PYTHON_CLIENT_MEM_FRACTION=.6
# %env XLA_PYTHON_CLIENT_ALLOCATOR=platform
# Out:
# env: XLA_PYTHON_CLIENT_MEM_FRACTION=.6

# %%
import jax
import equinox as eqx
import logging
import git
import numpy as np
import matplotlib.pyplot as plt
from jax import numpy as jnp
from dataclasses import asdict
from typing import cast

from rigid_flows.data import DataWithAuxiliary
from rigid_flows.density import KeyArray, OpenMMDensity
from rigid_flows.flow import RigidWithAuxiliary, build_flow
from rigid_flows.reporting import Reporter
from rigid_flows.specs import ExperimentSpecification
from rigid_flows.train import run_training_stage
from rigid_flows.utils import scanned_vmap

from flox._src.flow.api import Transform
from flox.flow import Pipe
from flox.util import key_chain
# Out:
# 2023-05-25 16:55:02.079169: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
logging.getLogger().setLevel(logging.INFO)

def setup_model(key: KeyArray, specs: ExperimentSpecification):
    chain = key_chain(key)

    logging.info("Loading base density.")
    if specs.model.base.num_samples is not None:
        logging.info(f'  taking maximum {specs.model.base.num_samples} samples from MD')
    base = OpenMMDensity.from_specs(
        specs.model.use_auxiliary, specs.model.base
    )

    logging.info(f"Loading target density.")
    if specs.model.target.num_samples is not None:
        logging.info(f'  taking maximum {specs.model.target.num_samples} samples from MD')
    target = OpenMMDensity.from_specs(
        specs.model.use_auxiliary, specs.model.target
    )

    logging.info(f"Setting up flow model.")
    flow = build_flow(
        next(chain),
        specs.model.base.num_molecules,
        specs.model.use_auxiliary,
        specs.model.flow,
    )

    if specs.model.pretrained_model_path is not None:
        logging.info(
            f"Loading pre-trained model from {specs.model.pretrained_model_path}."
        )
        flow = cast(
            Pipe[DataWithAuxiliary, RigidWithAuxiliary],
            eqx.tree_deserialise_leaves(
                specs.model.pretrained_model_path, flow
            ),
        )

    return base, target, flow


def train(
    key: KeyArray,
    run_dir: str,
    specs: ExperimentSpecification,
    base: OpenMMDensity,
    target: OpenMMDensity,
    flow: Transform[DataWithAuxiliary, DataWithAuxiliary],
    tot_iter: int,
    loss_reporter: list | None = None,
) -> Transform[DataWithAuxiliary, DataWithAuxiliary]:
    chain = key_chain(key)
    repo = git.Repo(search_parent_directories=True)
    branch = repo.active_branch.name
    sha = repo.head.object.hexsha

    log = asdict(specs)
    log["git"] = {"branch": branch, "sha": sha}
    logging.info(f"Starting training.")
    reporter = Reporter(
        base,
        target,
        run_dir,
        specs.reporting,
        scope=None,
    )
    reporter.with_scope(f"initial").report_model(next(chain), flow, tot_iter)
    for stage, train_spec in enumerate(specs.train):
        flow = run_training_stage(
            next(chain),
            base,
            target,
            flow,
            train_spec,
            reporter.with_scope(f"training_stage_{stage}"),
            tot_iter,
            loss_reporter,
        )
        tot_iter += train_spec.num_iterations
    return flow

def count_params(model):
    return jax.tree_util.tree_reduce(
        lambda s, n: s + n.size if eqx.is_array(n) else s, model, jnp.zeros((), dtype=jnp.int32)).item()

def jitvmap(fn, batch_size=None):
    if batch_size is None:
        return jax.jit(jax.vmap(fn))
    else:
        return jax.jit(scanned_vmap(fn, batch_size))

hist_kwargs = {"bins": "auto", "density": True, "alpha": 0.5}

# %%
logdir = "testing"
specs_file = "testing.yaml"
specs = ExperimentSpecification.load_from_file(specs_file)

chain = key_chain(specs.seed)
base, target, flow = setup_model(next(chain), specs)
model = base.omm_model.model

tot_iter = specs.global_step if specs.global_step is not None else 0

print(f'tot flow parameters: {count_params(flow):_}')
# Out:
# INFO:root:Loading base density.
# INFO:root:  taking maximum 10000 samples from MD
# INFO:root:Loading OpenMM model specs from ../MDdata/ice/trajectories/model-iceXI_T250_N16.json
# INFO:root:Loading data from ../MDdata/ice/trajectories/MDtraj-iceXI_T250_N16.npz
# INFO:root:Loading target density.
# INFO:root:  taking maximum 0 samples from MD
# INFO:root:Loading OpenMM model specs from ../MDdata/ice/trajectories/model-iceXI_T100_N16.json
# INFO:root:Setting up flow model.
# /home/mi/minvernizzi/mambaforge/envs/flox/lib/python3.10/site-packages/equinox/nn/_normalisation.py:84: UserWarning: LayerNorm(elementwise_affine=...) is deprecated in favour of LayerNorm(use_weight=...) and LayerNorm(use_bias=...)
#   warnings.warn(
# tot flow parameters: 290_896

# %%
try:
    ref_file = f"../MDdata/ice/DeltaF_estimates/DF-{specs.model.base}-{specs.model.target}.txt"
    reference_deltaF, reference_deltaF_std = np.loadtxt(ref_file, unpack=True)
except FileNotFoundError:
    reference_deltaF, reference_deltaF_std = None, None

reference_deltaF, reference_deltaF_std
# Out:
# (-669.7109, 0.05418)

# %%
num_samples = 1_000

keys = jax.random.split(next(chain), num_samples)
base_tr = jitvmap(base.sample)(keys)

mapped_tr = jitvmap(flow.forward)(base_tr.obj)

if target.data is not None:
    keys = jax.random.split(next(chain), num_samples)
    target_tr = jitvmap(target.sample)(keys)

logw = base_tr.ldj + mapped_tr.ldj - jitvmap(target.potential)(mapped_tr.obj)
(jnp.log(len(logw)) - jax.scipy.special.logsumexp(logw)).item()
# Out:
# -659.6427612304688

# %%
toPBC = True
model.plot_2Dview(base_tr.obj.pos.reshape(-1, model.n_atoms, 3), toPBC=toPBC, title='base')
model.plot_2Dview(mapped_tr.obj.pos.reshape(-1, model.n_atoms, 3), toPBC=toPBC, title='mapped')
if target.data is not None:
    model.plot_2Dview(target_tr.obj.pos.reshape(-1, model.n_atoms, 3), toPBC=toPBC, title='target')

# %%
# %%time

# !cp {specs_file} {logdir}/config.yaml

loss_reporter = []
flow = train(next(chain), logdir, specs, base, target, flow, tot_iter, loss_reporter)
# Out:
# INFO:root:Starting training.
# INFO:root:preparing report
# INFO:root:no data for target
# INFO:root:sampling from prior
# INFO:root:sampling from model
# INFO:root:Saving artifacts to testing/initial
# INFO:root:Saving model to testing/initial/model.eqx
# INFO:root:reporting ESS = 1.4206159114837646
# Epoch: 1/5:   0%|          | 0/1000 [00:05<?, ?it/s]
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File <timed exec>:4
#
# Cell In[4], line 69, in train(key, run_dir, specs, base, target, flow, tot_iter, loss_reporter)
#      67 reporter.with_scope(f"initial").report_model(next(chain), flow, tot_iter)
#      68 for stage, train_spec in enumerate(specs.train):
# ---> 69     flow = run_training_stage(
#      70         next(chain),
#      71         base,
#      72         target,
#      73         flow,
#      74         train_spec,
#      75         reporter.with_scope(f"training_stage_{stage}"),
#      76         tot_iter,
#      77         loss_reporter,
#      78     )
#      79     tot_iter += train_spec.num_iterations
#      80 return flow
#
# File /srv/data/minvernizzi/notebook/water/rigid-flows/rigid_flows/train.py:216, in run_training_stage(key, base, target, flow, training_specs, reporter, tot_iter, loss_reporter)
#     210 pbar = tqdm(
#     211     range(training_specs.num_iters_per_epoch),
#     212     desc=f"Epoch: {1+num_epoch}/{training_specs.num_epochs}",
#     213 )
#     215 for _ in pbar:
# --> 216     loss, flow, opt_state, report = step(next(chain), flow, opt_state)
#     217     pbar.set_postfix({"loss": loss})
#     218     tf.summary.scalar(f"loss/total/{reporter.scope}", loss, tot_iter)
#
# File /srv/data/minvernizzi/notebook/water/rigid-flows/rigid_flows/utils.py:44, in jit_and_cleanup_cache.<locals>.wrapper(*args, **kwargs)
#      41 static, static_tree_def = jax.tree_util.tree_flatten(static)
#      42 static = tuple(static)
# ---> 44 dynamic_out, static_out = jitted_call(args, kwargs, static, static_tree_def)
#      45 return cast(R, eqx.combine(dynamic_out, static_out.value))
#
#     [... skipping hidden 12 frame]
#
# File /srv/data/minvernizzi/notebook/water/rigid-flows/rigid_flows/utils.py:31, in jit_and_cleanup_cache.<locals>.jitted_call(args, kwargs, static, static_tree_def)
#      29 args = eqx.combine(args, args_static)
#      30 kwargs = cast(Mapping, eqx.combine(kwargs, kwargs_static))
# ---> 31 out = fn(*args, **kwargs)  # type: ignore
#      32 dynamic_out, static_out = eqx.partition(out, eqx.is_array)  # type: ignore
#      33 return dynamic_out, Static(static_out)
#
# File /srv/data/minvernizzi/notebook/water/rigid-flows/rigid_flows/train.py:185, in train_fn.<locals>.train_step(key, flow, opt_state)
#     179 def train_step(
#     180     key: KeyArray,
#     181     flow: Transform[DataWithAuxiliary, DataWithAuxiliary],
#     182     opt_state: OptState,
#     183 ):
#     184     loss_fn = init_losses(key)#, flow)
# --> 185     return update_fn(optim, loss_fn)(flow, opt_state)
#
# File /srv/data/minvernizzi/notebook/water/rigid-flows/rigid_flows/train.py:119, in update_fn.<locals>.update(flow, opt_state)
#     110 def update(
#     111     flow: Transform[DataWithAuxiliary, DataWithAuxiliary],
#     112     opt_state: OptState,
#     113 ):
#     114     (loss, report), grad = eqx.filter_value_and_grad(loss_fn, has_aux=True)(flow)
#     116     grad = (
#     117         lenses.bind(grad)
#     118         .Recur(EuclideanToRigidTransform)
# --> 119         .modify(lambda node: jax.tree_map(lambda x: jnp.zeros_like(x), node))
#     120     )
#     122     updates, opt_state = optim.update(grad, opt_state)  # type: ignore
#     123     flow = cast(
#     124         Transform[DataWithAuxiliary, DataWithAuxiliary],
#     125         eqx.apply_updates(flow, updates),
#     126     )
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/ui/__init__.py:241, in BoundLens.modify(self, func)
#     232 def modify(self, func: Callable[[A], B]) -> T:
#     233     """Apply a function to the focus.
#     234
#     235     >>> from lenses import bind
#    (...)
#     239     [1, 12, 3]
#     240     """
# --> 241     return self._optic.over(self._state, func)
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/optics/base.py:202, in LensLike.over(self, state, fn)
#     200 pure = lambda a: Identity(a)
#     201 func = lambda a: Identity(fn(a))
# --> 202 return self.apply(func, pure, state).unwrap()
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/optics/base.py:142, in LensLike.apply(self, f, pure, state)
#     134 def apply(self, f, pure, state):
#     135     """Runs the lens over the `state` applying `f` to all the foci
#     136     collecting the results together using the applicative functor
#     137     functions defined in `lenses.typeclass`. `f` must return an
#    (...)
#     140     pure form of the functor returned by `f`.
#     141     """
# --> 142     return self.func(Functorisor(pure, f), state)
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/optics/base.py:362, in Traversal.func(self, f, state)
#     361 def func(self, f, state):
# --> 362     foci = list(self.folder(state))
#     363     if foci == []:
#     364         return f.pure(state)
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/optics/traversals.py:144, in RecurTraversal.folder(self, state)
#     142 for attr in sorted(state.__dict__):
#     143     substate = getattr(state, attr)
# --> 144     for focus in self.folder(substate):
#     145         yield focus
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/optics/traversals.py:139, in RecurTraversal.folder(self, state)
#     137 elif self.can_iter(state):
#     138     for substate in hooks.to_iter(state):
# --> 139         for focus in self.folder(substate):
#     140             yield focus
#     141 elif hasattr(state, "__dict__"):
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/optics/traversals.py:144, in RecurTraversal.folder(self, state)
#     142 for attr in sorted(state.__dict__):
#     143     substate = getattr(state, attr)
# --> 144     for focus in self.folder(substate):
#     145         yield focus
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/optics/traversals.py:139, in RecurTraversal.folder(self, state)
#     137 elif self.can_iter(state):
#     138     for substate in hooks.to_iter(state):
# --> 139         for focus in self.folder(substate):
#     140             yield focus
#     141 elif hasattr(state, "__dict__"):
#
#     [... skipping similar frames: RecurTraversal.folder at line 139 (1468 times), RecurTraversal.folder at line 144 (1466 times)]
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/optics/traversals.py:144, in RecurTraversal.folder(self, state)
#     142 for attr in sorted(state.__dict__):
#     143     substate = getattr(state, attr)
# --> 144     for focus in self.folder(substate):
#     145         yield focus
#
#     [... skipping similar frames: RecurTraversal.folder at line 139 (1 times)]
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/optics/traversals.py:139, in RecurTraversal.folder(self, state)
#     137 elif self.can_iter(state):
#     138     for substate in hooks.to_iter(state):
# --> 139         for focus in self.folder(substate):
#     140             yield focus
#     141 elif hasattr(state, "__dict__"):
#
# File ~/mambaforge/envs/flox/lib/python3.10/site-packages/lenses/optics/traversals.py:135, in RecurTraversal.folder(self, state)
#     134 def folder(self, state):
# --> 135     if isinstance(state, self.cls):
#     136         yield state
#     137     elif self.can_iter(state):
#
# File ~/mambaforge/envs/flox/lib/python3.10/abc.py:119, in ABCMeta.__instancecheck__(cls, instance)
#     117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
# --> 119     return _abc_instancecheck(cls, instance)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
plt.plot(loss_reporter, label='KL loss')
if reference_deltaF is not None:
    plt.axhline(reference_deltaF, c="k", ls=":", label='MD reference')
plt.xlim(0, len(loss_reporter))
plt.xlabel('iterations')
plt.ylabel('$\Delta F$')
plt.legend()
plt.show()

# %%
mapped_tr = jitvmap(flow.forward)(base_tr.obj)

# %%
model.plot_2Dview(base_tr.obj.pos.reshape(-1, model.n_atoms, 3),   toPBC=toPBC, title='base')
model.plot_2Dview(mapped_tr.obj.pos.reshape(-1, model.n_atoms, 3), toPBC=toPBC, title='mapped')
if target.data is not None:
    model.plot_2Dview(target_tr.obj.pos.reshape(-1, model.n_atoms, 3), toPBC=toPBC, title='target')

# %%
def ess(logw):
    return jnp.exp(2*jax.scipy.special.logsumexp(logw)-jax.scipy.special.logsumexp(2*logw))

## NB: base_tr.ldj = jax.vmap(base.potential)(base_tr.obj)
logw = base_tr.ldj + mapped_tr.ldj - jax.vmap(target.potential)(mapped_tr.obj)

plt.hist(jnp.exp(logw-logw.max()), bins=100)
plt.yscale('log')
plt.show()

print(f'ESS = {ess(logw):g}  ->  {ess(logw)/len(logw):.2%}')

# %%
ene_fn = jitvmap(target.potential)
base_ene = ene_fn(base_tr.obj)
mapped_ene = ene_fn(mapped_tr.obj)
if target.data is not None:
    target_ene = ene_fn(target_tr.obj)

# %%
plt.hist(base_ene, **hist_kwargs, label='base')
plt.hist(mapped_ene, **hist_kwargs, label='mapped')
if target.data is not None:
    plt.hist(target_ene, **hist_kwargs, label='target')
plt.hist(mapped_ene, weights=np.exp(logw-jax.scipy.special.logsumexp(logw)), bins=75, histtype='step', density=True, label='reweighted')
plt.xlabel('total energy')
plt.legend()
plt.show()

# %%
r_range = [0.2, np.diag(model.box).min()]
n_bins = 300
plt.title('Oxygen-Oxygen')
model.plot_rdf(base_tr.obj.pos.reshape(-1, model.n_atoms, 3), r_range=r_range, n_bins=n_bins, label='base')
model.plot_rdf(mapped_tr.obj.pos.reshape(-1, model.n_atoms, 3), r_range=r_range, n_bins=n_bins, label='mapped')
if target.data is not None:
    model.plot_rdf(target_tr.obj.pos.reshape(-1, model.n_atoms, 3), r_range=r_range, n_bins=n_bins, label='target')
plt.axvline(model.box.max()/2, c='k', ls=':', alpha=.5)
plt.legend()
plt.show()

# %%
## TFEP
deltaF = (jnp.log(len(logw)) - jax.scipy.special.logsumexp(logw)).item()
print(f'Estimated deltaF from TFEP (below) = {deltaF:g}')
if reference_deltaF is not None:
    print(f'                  Reference deltaF = {reference_deltaF:g}')

# %%
def estimate_deltaF(key, num_samples, base):
    keys = jax.random.split(key, num_samples)
    base_tr = jitvmap(base.sample)(keys)
    mapped_tr = jitvmap(flow.forward)(base_tr.obj)
    logw = base_tr.ldj + mapped_tr.ldj - jitvmap(target.potential)(mapped_tr.obj)
    return (jnp.log(len(logw)) - jax.scipy.special.logsumexp(logw)).item()

eval_base = OpenMMDensity.from_specs(specs.model.use_auxiliary, specs.model.base, np.s_[-specs.model.base.num_samples:])
eval_base.data.pos.shape[0]

# %%
from tqdm import trange

iterations = 5
n_samples = 1000 

eval_deltaFs = np.zeros(iterations)
for i in trange(iterations):
    eval_deltaFs[i] = estimate_deltaF(next(chain), n_samples, eval_base)
    print(eval_deltaFs[i], end='\r')
eval_deltaFs.mean(), eval_deltaFs.std()
print(f'deltaF = {eval_deltaFs.mean():g} +/- {eval_deltaFs.std():g}')

# %%
xlim = [0, len(eval_deltaFs)]
plt.plot(eval_deltaFs, '.', c='orange', label='testing')
x = 2 * [eval_deltaFs.mean()]
plt.fill_between(xlim, x-eval_deltaFs.std(), x+eval_deltaFs.std(), color='orange', alpha=0.3)
plt.axhline(eval_deltaFs.mean(), c='orange')
if reference_deltaF is not None:
    plt.axhline(reference_deltaF, c='k', ls=":", label='reference')
    x = np.array(2 * [reference_deltaF])
    plt.fill_between(xlim, x-reference_deltaF_std, x+reference_deltaF_std, color='k', alpha=0.1)
plt.xlim(xlim)
plt.legend()
plt.show()
